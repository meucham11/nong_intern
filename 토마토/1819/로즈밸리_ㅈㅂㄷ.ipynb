# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime
from datetime import timedelta
import pickle


import warnings
warnings.filterwarnings(action='ignore') 

# 사이킷런
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 회귀
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# 사이킷런
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 회귀
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
pd.set_option('display.max_row', 5000)
pd.set_option('display.max_columns', 100)

from matplotlib import font_manager, rc
import matplotlib
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()

rc('font', family=font_name)

matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 데이터 로드

# %%
sang18_tomato_raw=pd.read_excel('C:\\농업기술원\\1차\\2018\\2018-2019 토마토_생육(원본)'+'/로즈밸리_정병두_생육.xlsx',sheet_name='1819생육')

# %%
#env18_tomato_raw=pd.read_excel('C:\\농업기술원\\1차\\2018\\2018-2019 토마토_환경(원본)'+'/로즈밸리_정병두_환경.xlsx')

# %%
#with open("C:\\농업기술원\\1차\\2018\\2018-2019 토마토_환경(원본)\\로즈밸리_정병두_환경.pickle","wb") as fw:
#    pickle.dump(env18_tomato_raw, fw)

# %%
with open("C:\\농업기술원\\1차\\2018\\2018-2019 토마토_환경(원본)\\로즈밸리_정병두_환경.pickle","rb") as fr:
    env18_tomato_raw = pickle.load(fr)

# %% [markdown]
# # 필요한 데이터 컬럼 고르기

# %%
sang_data=sang18_tomato_raw[['Date','WeekNum','Sample','초장','생장길이','화방높이','줄기굵기']]

# %%
env_data=env18_tomato_raw[['date','내부온도','내부습도','CO2','누적일사량']]

# %% [markdown]
# # 사용자 지정함수

# %%
# 생육에 주차 추가
def add_weeknum(sang_df):
    sang_df['diff']=sang_df['WeekNum'].shift(1)
    sang_df['diff2']=sang_df['WeekNum']-sang_df['diff']
    
    num=-1
    test_week=[]
    for i in range(len(sang_df)):
        if sang_df['diff2'].loc[i]!=0:
            num+=1
            test_week.append(num)
        else:
            test_week.append(num)
    del sang_df['diff']
    del sang_df['diff2']
    return test_week

# %%
# 12시간 짤라서 Date 추가
def env_add_Date(env_df,생육조사기간):
    df=pd.DataFrame()
    for i in range(len(생육조사기간)-1):
        start_i = 생육조사기간[i]+timedelta(hours=12)
        end_i = 생육조사기간[i+1]+timedelta(hours=12)

        df2 = env_df[(env_df['date']>=start_i) & (env_df['date']<end_i)]
        df2['Date']=생육조사기간[i+1]


        df=pd.concat([df,df2])
    return df

# %%
def cumsum_to_value(df):
    #누적일사량 해결
    df['lag_누적일사량']=df['누적일사량'].shift(1)
    df['일사량2']=df['누적일사량']-df['lag_누적일사량']

    #음수를 0으로 치환 NA를 0으로 치환
    df['일사량2_치환']=df['일사량2'].apply(lambda x : 0 if x<0 else x)
    df['일사량']=df['일사량2_치환'].fillna(0)

    del df['lag_누적일사량']
    del df['일사량2']
    del df['일사량2_치환']
    return df

# %%
# 생육 Date와 환경 Date 매칭
def match_test_weeknum(sang_data,env_data):
    dic=dict(zip(sang_data['Date'],sang_data['주차']))
    result=env_data.replace({"Date":dic})["Date"]
    return result

# %%
def box_to_find_outlier(env_data,name,cols):
    plt.figure(figsize=[13,8])
    plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 1, wspace = 0.5)
    cnt_cols = 2
    cnt_rows = 2 
    
    print(name[:-3:])
    for k,env in enumerate(cols):
        plt.subplot(cnt_rows, cnt_cols, k+1)

        
        sns.boxplot(data=env_data,x='주차',y=env)
        plt.title(name[:-3:]+'_'+env)
        plt.tight_layout()
    plt.show()
    print('---------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------------------------------------------')

# %%
def remove_outlier(df,col):
    cut_df=pd.DataFrame()
    for i in range(len(df['주차'].unique())):
        k=df[df['주차']==i+1]
        
        
        q1 = k[col].quantile(0.25)
        q3 = k[col].quantile(0.75)

        iqt = 1.5 * (q3 - q1)

        # 이상치 제거

        k=k[(k[col] < (q3 + iqt)) & (k[col] > (q1 - iqt))]
        
        cut_df=pd.concat([cut_df,k])
    return cut_df

# %%
def removed_outlier_pivot(df,col,aggfunc):
    cut_df=remove_outlier(df,col)
    result = cut_df.pivot_table(index='주차',
                               values=col,
                               aggfunc=aggfunc).reset_index(drop=False)

    return result

# %%
def pivot_lineplot(df,name,):
    plt.figure(figsize=[13,8])
    plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 1, wspace = 0.5)
    cnt_cols = 2
    cnt_rows = 2 
    
    print(name[:-3:])
    for k,env in enumerate(cols):
        plt.subplot(cnt_rows, cnt_cols, k+1)

        
        sns.boxplot(data=env_data,x='주차',y=env)
        plt.title(name[:-3:]+'_'+env)
    plt.show()
    print('---------------------------------------------------------------------------------------------')
    print('---------------------------------------------------------------------------------------------')

# %%
def 이중축그래프(data,x,y,title,hue="Sample"):
    fig, ax0=plt.subplots(figsize=(15,7))

    ax1 = ax0.twinx()
    sns.lineplot(data=data,
                y=y,
                x='Date',
                hue=hue,ax=ax0)
    sns.lineplot(data=data,
                y=x,
                x='Date',ax=ax1,color='green')
    plt.title(title)
    plt.plot()

# %%
def 다항회귀함수(data,degree,x,y,title,xlab,ylab):
    poly_features = PolynomialFeatures(degree=degree)
    pred_x=np.linspace(16,24,len(data))

    X = np.array(data[x]).reshape(-1,1)
    y = np.array(data[y]).reshape(-1,1)
    X_poly = poly_features.fit_transform(X)
    lr = LinearRegression(fit_intercept=False)
    lr.fit(X_poly,y)
    sort_df=pd.DataFrame({'x':X.flatten(), 
                        'y':lr.predict(X_poly).flatten()}).sort_values('x')

    
    plt.figure(figsize=(15,8))
    plt.scatter(X.flatten(),y.flatten(),s=3, c="black")
    plt.plot(sort_df['x'], sort_df['y'])
    plt.title(title)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.show()

# %% [markdown]
# # 데이터 편집

# %%
sang_data['주차']=add_weeknum(sang_data)

# %%
# 다음 측정일 Date 추가
생육조사기간=sorted(list(set(list(sang_data['Date']))))
env_data=env_add_Date(env_data,생육조사기간)

# %%
# 환경 데이터에 주차 컬럼 추가
env_data['주차']=match_test_weeknum(sang_data,env_data)

# %%
# 누적을 증가량으로 바꿔주기
base_col=['date','Date','주차']
cumsum_list=['누적일사량']
cumsum_col=base_col+cumsum_list
cumsum_df=cumsum_to_value(env_data[cumsum_col])
env_data['일사량']=cumsum_df['일사량']
del env_data['누적일사량']

# %%
# 환경 데이터 변수명
avg_list=['내부온도','내부습도','CO2']
sum_list=['일사량']

cols=avg_list+sum_list

# %%
# 이상치 파악하기
name='로즈밸리_ㅈㅂㄷ'
box_to_find_outlier(env_data,name,cols)
env_data=env_data.reset_index(drop=True)
# Out:
# 로즈밸리_
# ---------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# 이상치가 많다는 것을 알 수 있다.

# %% [markdown]
# # 생육 이상치 제거

# %%
# 평균으로 집계할 변수와, 합으로 집계할 변수 설정하기
base_col=['Date','주차']
sang_remove_target=['생장길이']

# %%
i=0
for col in sang_remove_target:
    df=sang_data[[col,'주차']]

    # 이상치 제거
    my_df = remove_outlier(df,col)


    if i==0:
        sang_result = my_df
        i+=1
        continue

    sang_result = pd.merge(sang_result,my_df,how='inner',on='주차')

# %%
sang_result=sang_data.iloc[sang_result.index,:]

# %% [markdown]
# # 환경 이상치 제거 후 집계

# %%
# 평균으로 집계할 변수와, 합으로 집계할 변수 설정하기
base_col=['date','Date','주차']
avg_list=['내부온도','내부습도','CO2']
sum_list=['일사량']
cols=avg_list+sum_list
aggfunc=['mean']*len(avg_list)+['sum']*len(sum_list)

# %%
# evn데이터 이상치 제거

i=0
for col,agg in zip(cols,aggfunc):
    df=env_data[[col,'주차']]

    # 이상치 제거, 피봇
    my_pivot = removed_outlier_pivot(df,col,agg)


    if i==0:
        env_pivot = my_pivot
        i+=1
        continue

    env_pivot = pd.merge(env_pivot,my_pivot,how='inner',on='주차')

# %% [markdown]
# # 집계 데이터 주차별로 시각화

# %%
plt.figure(figsize=[13,8])
plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 1, wspace = 0.5)
cnt_cols = 2
cnt_rows = 2

for k,col in enumerate(cols):
    plt.subplot(cnt_rows, cnt_cols, k+1)
    sns.lineplot(data=env_pivot,x='주차',y=col)
    plt.title(name[:-3:]+'_'+col)
    plt.tight_layout()
plt.show()

# %% [markdown]
# # 분석

# %% [markdown]
# # 온도에 따른 생장길이

# %%
# 생육과 환경조인
sang_env = pd.merge(sang_result,env_pivot,on='주차',how='inner')

# %%
plt.figure(figsize=(15,10))
이중축그래프(data=sang_env,x='내부온도',y='생장길이',
      title='샘플별 생장길이와 온도')

# %%
plt.figure(figsize=(15,10))
이중축그래프(data=sang_env,x='내부온도',y='생장길이', hue=None,
      title='샘플별 생장길이와 온도')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=sang_env, x= "내부온도", y = "생장길이")

# %%
sang_env[['생장길이','내부온도','내부습도','CO2','일사량']].corr()
# Out:
#           생장길이      내부온도      내부습도       CO2       일사량
# 생장길이  1.000000  0.627459 -0.256016 -0.474428  0.212275
# 내부온도  0.627459  1.000000 -0.631392 -0.658374  0.624293
# 내부습도 -0.256016 -0.631392  1.000000  0.420459 -0.811323
# CO2  -0.474428 -0.658374  0.420459  1.000000 -0.171803
# 일사량   0.212275  0.624293 -0.811323 -0.171803  1.000000

# %% [markdown]
# 선형성이 있다고는 말하기는 상관관계가 낮다

# %%
for i in ['내부온도','내부습도','CO2','일사량']:
    다항회귀함수(data = sang_env,x=i,y='생장길이',degree=4,
          title='1주일간'+i+'와 생장길이의 관계',xlab=i,ylab='생장길이')

# %%
df = sang_env.pivot_table(index="주차",
                         values=['생장길이','내부온도','내부습도','CO2','일사량'],
                         aggfunc='mean').reset_index(drop=True)

# %%
for i in ['내부온도','내부습도','CO2','일사량']:
    다항회귀함수(data = df,x=i,y='생장길이',degree=4,
      title='1주일간'+i+'와 생장길이의 관계',xlab=i,ylab='생장길이')

# %% [markdown]
# # 양액

# %% [markdown]
# 공급sum < 배액sum 이라 데이터가 이상하다. 맞죠..? </br>
# 양액을 고려하지 않고 모델을 만든다.

# %% [markdown]
# # 지연변수 생성 (주단위)
# 여러 실험을 통해 3주 까지 보는게 더 낫다

# %%
lag_result=env_pivot
for i in range(3):
    raw_col=env_pivot.columns[1:]
    later_df=env_pivot.iloc[:,1:].shift(periods=i+1)
    later_col=['_'+str(i+1)+'주전_'+j for j in list(raw_col)]
    later_df.columns=later_col

    lag_result=pd.concat([lag_result,later_df],axis=1)

# %%
env_pivot.head(5)
# Out:
#    주차       내부온도       내부습도         CO2     일사량
# 0   1  23.914369  83.754904  393.053229  3554.0
# 1   2  22.008672  75.465625  386.940711  9198.0
# 2   3  20.652535  72.164421  381.112725  7841.0
# 3   4  19.763543  79.572989  384.140959  2747.0
# 4   5  19.479516  76.286539  430.096432  9591.0

# %%
lag_result.head(5)
# Out:
#    주차       내부온도       내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도  \
# 0   1  23.914369  83.754904  393.053229  3554.0        NaN        NaN
# 1   2  22.008672  75.465625  386.940711  9198.0  23.914369  83.754904
# 2   3  20.652535  72.164421  381.112725  7841.0  22.008672  75.465625
# 3   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 4   5  19.479516  76.286539  430.096432  9591.0  19.763543  79.572989
#
#      _1주전_CO2  _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  \
# 0         NaN       NaN        NaN        NaN         NaN       NaN
# 1  393.053229    3554.0        NaN        NaN         NaN       NaN
# 2  386.940711    9198.0  23.914369  83.754904  393.053229    3554.0
# 3  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 4  384.140959    2747.0  20.652535  72.164421  381.112725    7841.0
#
#    _3주전_내부온도  _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 0        NaN        NaN         NaN       NaN
# 1        NaN        NaN         NaN       NaN
# 2        NaN        NaN         NaN       NaN
# 3  23.914369  83.754904  393.053229    3554.0
# 4  22.008672  75.465625  386.940711    9198.0

# %%
merge_dataset = pd.merge(sang_result,lag_result,how='inner',on='주차')

# %% [markdown]
# # 생장길이 예측

# %% [markdown]
# # xgboost

# %%
from sklearn.datasets import load_boston
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import KFold

# %%
def xgb(df,Y,parameters):

    test_size=0.25
    
    xgb_model = xgboost.XGBRegressor(n_estimators=100, gamma=0,
                               colsample_bytree=1, max_depth=7)

    
    xgb_regressor = GridSearchCV(xgb_model,parameters,scoring='neg_mean_squared_error',cv=10)

    x_train=df.iloc[:,[2,3,4,5,8,12]]
    y_train=df[Y]
    
    
    
    
    xgb_regressor.fit(x_train,y_train)
    print(xgb_regressor.best_params_)
    
    eta=xgb_regressor.best_params_['eta']
    learning_rate=xgb_regressor.best_params_['learning_rate']
    subsample = xgb_regressor.best_params_['subsample']
    
    # Kfold
    X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=test_size)
    xgb_model = xgboost.XGBRegressor(n_estimators=100,  gamma=0,colsample_bytree=1, max_depth=7,
                                     learning_rate=learning_rate,
                                     subsample=subsample,
                                     eta=eta
                           )

    print(len(X_train), len(X_test))
    
    xgb_model.fit(X_train,y_train)
    predictions = xgb_model.predict(X_test)
    RMSE = mean_squared_error(y_test, predictions)**0.5
    print(RMSE)
    
    
    xgboost.plot_importance(xgb_model)
    
    
    plt.figure(figsize=[24,12])
    sns.lineplot(x=range(len(predictions)),y=predictions,label="pred")
    sns.lineplot(x=range(len(y_test)),y=y_test,label="Test")
    plt.show()
   
    plt.figure(figsize=[24,12])
    sns.lineplot(x=range(len(y_test)),y=y_test-predictions,label="Test")
    plt.title("차이")
    plt.show()
    print("--------------------------------------------------------------------------------------------")
    print("--------------------------------------------------------------------------------------------")
    print("--------------------------------------------------------------------------------------------")
    
    result_df = pd.DataFrame({'y_test':y_test,
                             'pred':predictions,
                             '차이':abs(y_test-predictions)})
    result_df=result_df.sort_values('차이',ascending=False).head(6)
    
    
    return result_df

# %%
model_dataset.head(10)
# Out:
#     생장길이  주차       내부온도       내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도  \
# 34  20.8   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 35  23.2   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 36  26.0   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 37  28.4   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 38  23.4   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 39  26.0   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 40  25.0   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 41  26.5   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 42  23.5   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
# 43  24.8   4  19.763543  79.572989  384.140959  2747.0  20.652535  72.164421
#
#       _1주전_CO2  _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  \
# 34  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 35  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 36  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 37  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 38  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 39  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 40  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 41  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 42  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
# 43  381.112725    7841.0  22.008672  75.465625  386.940711    9198.0
#
#     _3주전_내부온도  _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 34  23.914369  83.754904  393.053229    3554.0
# 35  23.914369  83.754904  393.053229    3554.0
# 36  23.914369  83.754904  393.053229    3554.0
# 37  23.914369  83.754904  393.053229    3554.0
# 38  23.914369  83.754904  393.053229    3554.0
# 39  23.914369  83.754904  393.053229    3554.0
# 40  23.914369  83.754904  393.053229    3554.0
# 41  23.914369  83.754904  393.053229    3554.0
# 42  23.914369  83.754904  393.053229    3554.0
# 43  23.914369  83.754904  393.053229    3554.0

# %% [markdown]
# ## 튜닝1

# %%
2,3,4,5,8,12
# Out:
# (2, 3, 4, 5, 8, 12)

# %%
model_dataset=merge_dataset[['생장길이']+list(merge_dataset.columns[list(range(7,len(merge_dataset.columns)))])].dropna()

# %%
parameters = {'eta':[0.06,0.63,0.065],
              'learning_rate':[0.1,0.15,0.17,0.18],
              'subsample':[0.84,0.85,0.86]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.06, 'learning_rate': 0.17, 'subsample': 0.85}
# 293 98
# 2.793736698514183
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
#           Date  WeekNum  Sample  초장  생장길이  화방높이   줄기굵기  주차       내부온도  \
# 367 2019-04-24       17      12 NaN  15.0   6.5   5.21  32  20.367718
# 313 2019-03-27       13       5 NaN  13.0  39.0   9.15  28  18.496438
# 250 2019-02-13        7      12 NaN  20.2  52.0  14.72  22  16.928831
# 360 2019-04-24       17       5 NaN  17.0   7.0   5.19  32  20.367718
# 204 2019-01-16        3      11 NaN  19.8  37.5  11.39  18  14.787661
# 233 2019-02-07        6       5 NaN  16.0  31.5  12.44  21  14.539323
#
#           내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도    _1주전_CO2  \
# 367  81.406409  411.812480  7619.0  19.228631  80.694668  447.189237
# 313  82.386225  439.844363  8466.0  18.470048  81.126052  441.840662
# 250  83.617750  458.167161  6829.0  14.539323  88.140032  476.271528
# 360  81.406409  411.812480  7619.0  19.228631  80.694668  447.189237
# 204  86.456832  464.514020  3822.0  14.666382  84.068506  453.563323
# 233  88.140032  476.271528  3098.0  16.739717  82.808475  453.861318
#
#      _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  _3주전_내부온도  \
# 367    8723.0  18.612063  79.678730  439.896830    8563.0  18.730166
# 313    9569.0  17.827460  85.434618  444.963829    2800.0  17.802969
# 250    3098.0  16.739717  82.808475  453.861318    3463.0  15.298012
# 360    8723.0  18.612063  79.678730  439.896830    8563.0  18.730166
# 204    3822.0  13.814623  78.921044  436.832900    3703.0  15.564329
# 233    3463.0  15.298012  85.372852  450.001308    3428.0  14.787661
#
#      _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 367  80.260157  436.994617    9079.0
# 313  85.337100  448.315198    3434.0
# 250  85.372852  450.001308    3428.0
# 360  80.260157  436.994617    9079.0
# 204  84.839191  447.836727    3698.0
# 233  86.456832  464.514020    3822.0

# %%
parameters = {'eta':[0.06,0.63,0.065],
              'learning_rate':[0.1,0.15,0.17,0.18],
              'subsample':[0.84,0.85,0.86]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.06, 'learning_rate': 0.17, 'subsample': 0.85}
# 293 98
# 3.1090777857570346
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
#           Date  WeekNum  Sample  초장  생장길이  화방높이   줄기굵기  주차       내부온도  \
# 271 2019-02-27        9      10 NaN  27.0  52.0  13.27  24  17.899782
# 272 2019-02-27        9      11 NaN  26.0  47.0  12.08  24  17.899782
# 398 2019-05-15       20       8 NaN  16.5  19.5   7.24  35  21.327884
# 379 2019-05-02       18      12 NaN  12.5  16.5   6.80  33  18.505598
# 68  2018-10-24       43      12 NaN  30.2  49.0  12.04   6  19.263651
# 262 2019-02-27        9       1 NaN  12.0  34.0   9.51  24  17.899782
#
#           내부습도         CO2      일사량  _1주전_내부온도  _1주전_내부습도    _1주전_CO2  \
# 271  86.392462  464.711407   8875.0  15.042915  87.411093  465.216472
# 272  86.392462  464.711407   8875.0  15.042915  87.411093  465.216472
# 398  69.230404  421.688007  16658.0  20.850532  67.628241  433.793204
# 379  88.958306  425.543005   3037.0  20.367718  81.406409  411.812480
# 68   77.120237  436.988683   9577.0  19.479516  76.286539  430.096432
# 262  86.392462  464.711407   8875.0  15.042915  87.411093  465.216472
#
#      _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  _3주전_내부온도  \
# 271    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 272    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 398   15219.0  18.505598  88.958306  425.543005    3037.0  20.367718
# 379    7619.0  19.228631  80.694668  447.189237    8723.0  18.612063
# 68     9591.0  19.763543  79.572989  384.140959    2747.0  20.652535
# 262    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
#
#      _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 271  88.140032  476.271528    3098.0
# 272  88.140032  476.271528    3098.0
# 398  81.406409  411.812480    7619.0
# 379  79.678730  439.896830    8563.0
# 68   72.164421  381.112725    7841.0
# 262  88.140032  476.271528    3098.0

# %%
parameters = {'eta':[0.06,0.63,0.065],
              'learning_rate':[0.1,0.15,0.17,0.18],
              'subsample':[0.84,0.85,0.86]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.06, 'learning_rate': 0.17, 'subsample': 0.85}
# 293 98
# 2.9785685697872633
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
#           Date  WeekNum  Sample  초장  생장길이  화방높이   줄기굵기  주차       내부온도  \
# 271 2019-02-27        9      10 NaN  27.0  52.0  13.27  24  17.899782
# 379 2019-05-02       18      12 NaN  12.5  16.5   6.80  33  18.505598
# 298 2019-03-20       12       1 NaN  11.0   9.0   6.72  27  18.470048
# 81  2018-11-07       45       1 NaN  16.0  37.0   9.45   8  18.039504
# 83  2018-11-07       45       3 NaN  16.5  14.8   9.32   8  18.039504
# 233 2019-02-07        6       5 NaN  16.0  31.5  12.44  21  14.539323
#
#           내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도    _1주전_CO2  \
# 271  86.392462  464.711407  8875.0  15.042915  87.411093  465.216472
# 379  88.958306  425.543005  3037.0  20.367718  81.406409  411.812480
# 298  81.126052  441.840662  9569.0  17.827460  85.434618  444.963829
# 81   82.967108  433.399306  8115.0  17.576507  85.409435  412.519677
# 83   82.967108  433.399306  8115.0  17.576507  85.409435  412.519677
# 233  88.140032  476.271528  3098.0  16.739717  82.808475  453.861318
#
#      _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  _3주전_내부온도  \
# 271    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 379    7619.0  19.228631  80.694668  447.189237    8723.0  18.612063
# 298    2800.0  17.802969  85.337100  448.315198    3434.0  17.899782
# 81     2822.0  19.263651  77.120237  436.988683    9577.0  19.479516
# 83     2822.0  19.263651  77.120237  436.988683    9577.0  19.479516
# 233    3463.0  15.298012  85.372852  450.001308    3428.0  14.787661
#
#      _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 271  88.140032  476.271528    3098.0
# 379  79.678730  439.896830    8563.0
# 298  86.392462  464.711407    8875.0
# 81   76.286539  430.096432    9591.0
# 83   76.286539  430.096432    9591.0
# 233  86.456832  464.514020    3822.0

# %% [markdown]
# ## 튜닝2

# %%
parameters = {'eta':[0.065,0.07,0.8],
              'learning_rate':[0.09,0.1,0.11,0.12],
              'subsample':[0.85,0.88,0.9,0.92,0.95]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.065, 'learning_rate': 0.1, 'subsample': 0.9}
# 293 98
# 3.2313964535931254
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
#           Date  WeekNum  Sample  초장  생장길이  화방높이   줄기굵기  주차       내부온도  \
# 271 2019-02-27        9      10 NaN  27.0  52.0  13.27  24  17.899782
# 68  2018-10-24       43      12 NaN  30.2  49.0  12.04   6  19.263651
# 239 2019-02-07        6      11 NaN  27.0  44.0  14.06  21  14.539323
# 272 2019-02-27        9      11 NaN  26.0  47.0  12.08  24  17.899782
# 286 2019-03-13       11       1 NaN  11.0  18.0   8.60  26  17.827460
# 403 2019-05-22       21       1 NaN  19.3  10.0   6.53  36  22.073452
#
#           내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도    _1주전_CO2  \
# 271  86.392462  464.711407  8875.0  15.042915  87.411093  465.216472
# 68   77.120237  436.988683  9577.0  19.479516  76.286539  430.096432
# 239  88.140032  476.271528  3098.0  16.739717  82.808475  453.861318
# 272  86.392462  464.711407  8875.0  15.042915  87.411093  465.216472
# 286  85.434618  444.963829  2800.0  17.802969  85.337100  448.315198
# 403  76.873581  397.397569  8629.0  21.327884  69.230404  421.688007
#
#      _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  _3주전_내부온도  \
# 271    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 68     9591.0  19.763543  79.572989  384.140959    2747.0  20.652535
# 239    3463.0  15.298012  85.372852  450.001308    3428.0  14.787661
# 272    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 286    3434.0  17.899782  86.392462  464.711407    8875.0  15.042915
# 403   16658.0  20.850532  67.628241  433.793204   15219.0  18.505598
#
#      _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 271  88.140032  476.271528    3098.0
# 68   72.164421  381.112725    7841.0
# 239  86.456832  464.514020    3822.0
# 272  88.140032  476.271528    3098.0
# 286  87.411093  465.216472    2888.0
# 403  88.958306  425.543005    3037.0

# %%
parameters = {'eta':[0.065,0.07,0.8],
              'learning_rate':[0.09,0.1,0.11,0.12],
              'subsample':[0.85,0.88,0.9,0.92,0.95]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.065, 'learning_rate': 0.1, 'subsample': 0.9}
# 293 98
# 2.719242198293694
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
#           Date  WeekNum  Sample  초장  생장길이  화방높이   줄기굵기  주차       내부온도  \
# 271 2019-02-27        9      10 NaN  27.0  52.0  13.27  24  17.899782
# 68  2018-10-24       43      12 NaN  30.2  49.0  12.04   6  19.263651
# 313 2019-03-27       13       5 NaN  13.0  39.0   9.15  28  18.496438
# 362 2019-04-24       17       7 NaN  27.0  18.0   8.46  32  20.367718
# 286 2019-03-13       11       1 NaN  11.0  18.0   8.60  26  17.827460
# 113 2018-11-21       47      11 NaN  22.0  19.2  10.61  10  16.891631
#
#           내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도    _1주전_CO2  \
# 271  86.392462  464.711407  8875.0  15.042915  87.411093  465.216472
# 68   77.120237  436.988683  9577.0  19.479516  76.286539  430.096432
# 313  82.386225  439.844363  8466.0  18.470048  81.126052  441.840662
# 362  81.406409  411.812480  7619.0  19.228631  80.694668  447.189237
# 286  85.434618  444.963829  2800.0  17.802969  85.337100  448.315198
# 113  84.282720  434.465774  3324.0  16.304336  88.492737  400.496874
#
#      _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  _3주전_내부온도  \
# 271    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 68     9591.0  19.763543  79.572989  384.140959    2747.0  20.652535
# 313    9569.0  17.827460  85.434618  444.963829    2800.0  17.802969
# 362    8723.0  18.612063  79.678730  439.896830    8563.0  18.730166
# 286    3434.0  17.899782  86.392462  464.711407    8875.0  15.042915
# 113    2652.0  18.039504  82.967108  433.399306    8115.0  17.576507
#
#      _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 271  88.140032  476.271528    3098.0
# 68   72.164421  381.112725    7841.0
# 313  85.337100  448.315198    3434.0
# 362  80.260157  436.994617    9079.0
# 286  87.411093  465.216472    2888.0
# 113  85.409435  412.519677    2822.0

# %%
parameters = {'eta':[0.065,0.07,0.8],
              'learning_rate':[0.09,0.1,0.11,0.12],
              'subsample':[0.85,0.88,0.9,0.92,0.95]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.065, 'learning_rate': 0.1, 'subsample': 0.9}
# 293 98
# 3.244819446119332
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
#           Date  WeekNum  Sample  초장  생장길이  화방높이   줄기굵기  주차       내부온도  \
# 262 2019-02-27        9       1 NaN  12.0  34.0   9.51  24  17.899782
# 367 2019-04-24       17      12 NaN  15.0   6.5   5.21  32  20.367718
# 229 2019-02-07        6       1 NaN  14.0  24.0   9.74  21  14.539323
# 352 2019-04-17       16       9 NaN  15.0  45.0  11.40  31  19.228631
# 360 2019-04-24       17       5 NaN  17.0   7.0   5.19  32  20.367718
# 241 2019-02-13        7       1 NaN   9.8  34.0  13.88  22  16.928831
#
#           내부습도         CO2     일사량  _1주전_내부온도  _1주전_내부습도    _1주전_CO2  \
# 262  86.392462  464.711407  8875.0  15.042915  87.411093  465.216472
# 367  81.406409  411.812480  7619.0  19.228631  80.694668  447.189237
# 229  88.140032  476.271528  3098.0  16.739717  82.808475  453.861318
# 352  80.694668  447.189237  8723.0  18.612063  79.678730  439.896830
# 360  81.406409  411.812480  7619.0  19.228631  80.694668  447.189237
# 241  83.617750  458.167161  6829.0  14.539323  88.140032  476.271528
#
#      _1주전_일사량  _2주전_내부온도  _2주전_내부습도    _2주전_CO2  _2주전_일사량  _3주전_내부온도  \
# 262    2888.0  16.928831  83.617750  458.167161    6829.0  14.539323
# 367    8723.0  18.612063  79.678730  439.896830    8563.0  18.730166
# 229    3463.0  15.298012  85.372852  450.001308    3428.0  14.787661
# 352    8563.0  18.730166  80.260157  436.994617    9079.0  18.496438
# 360    8723.0  18.612063  79.678730  439.896830    8563.0  18.730166
# 241    3098.0  16.739717  82.808475  453.861318    3463.0  15.298012
#
#      _3주전_내부습도    _3주전_CO2  _3주전_일사량
# 262  88.140032  476.271528    3098.0
# 367  80.260157  436.994617    9079.0
# 229  86.456832  464.514020    3822.0
# 352  82.386225  439.844363    8466.0
# 360  80.260157  436.994617    9079.0
# 241  85.372852  450.001308    3428.0

# %% [markdown]
# ## 튜닝3

# %%
parameters = {'eta':[0.07,0.1,0.13],
              'learning_rate':[0.08,0.1,0.13,0.15,0.17,0.2,0.3,0.6],
              'subsample':[0.7,0.8,0.9]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.07, 'learning_rate': 0.13, 'subsample': 0.7}
# 318 107
# 2.910233751200524
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# 2.910233751200524

# %%
parameters = {'eta':[0.07,0.1,0.13],
              'learning_rate':[0.08,0.1,0.13,0.15,0.17,0.2,0.3,0.6],
              'subsample':[0.7,0.8,0.9]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.07, 'learning_rate': 0.13, 'subsample': 0.7}
# 318 107
# 2.79031767412507
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# 2.79031767412507

# %%
parameters = {'eta':[0.07,0.1,0.13],
              'learning_rate':[0.08,0.1,0.13,0.15,0.17,0.2,0.3,0.6],
              'subsample':[0.7,0.8,0.9]}
result = xgb(model_dataset,'생장길이',parameters=parameters)
merge_dataset.iloc[result.index,:]
# Out:
# {'eta': 0.07, 'learning_rate': 0.13, 'subsample': 0.7}
# 318 107
# 2.9563935706035203
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# 2.9563935706035203

# %% [markdown]
# # 수확과
# 모든 샘플의 수확과를 측정한게 아니라 1번,4번, 7번, 10번 샘플의 수확과만 측정했다..

# %%
harvest_data_raw = pd.read_excel('C:\\농업기술원\\1차\\2018\\2018-2019 토마토_생육(원본)'+'/로즈밸리_정병두_생육.xlsx',sheet_name='수확과')

# %% [markdown]
# 표본별로 수확된 과일의 개수가 차이가 있는가?

# %%
harvest_cnt = harvest_data_raw[['날짜','샘플','무게']].pivot_table(index=['날짜','샘플'],values='무게',aggfunc='count').reset_index()
harvest_cnt.columns=['날짜','샘플','개수']
harvest_cnt.head(7)
# Out:
#           날짜  샘플  개수
# 0 2018-10-24  10   2
# 1 2018-10-31   4   1
# 2 2018-10-31   7   2
# 3 2018-10-31  10   2
# 4 2018-11-07   1   3
# 5 2018-11-07   4   2
# 6 2018-11-07   7   1

# %%
harvest_cnt['날짜']=harvest_cnt['날짜'].astype(str)
harvest_cnt['샘플']=harvest_cnt['샘플'].astype(str)

# %%
x1 = np.array(harvest_cnt[harvest_cnt['샘플'] == '1']['개수'])
x2 = np.array(harvest_cnt[harvest_cnt['샘플'] == '4']['개수'])
x3 = np.array(harvest_cnt[harvest_cnt['샘플'] == '7']['개수'])
x4 = np.array(harvest_cnt[harvest_cnt['샘플'] == '10']['개수'])

# %% [markdown]
# ![분산분석로드맵](https://user-images.githubusercontent.com/34879309/98882835-82baa680-24d0-11eb-9c1e-3b338e719dba.PNG)
#
# 출처 :statedu.com

# %%
from scipy import stats
# 등분산 검정
print(stats.bartlett(x1,x2,x3,x4),stats.fligner(x1, x2, x3,x4) ,stats.levene(x1, x2, x3,x4), sep="\n")
# Out:
# BartlettResult(statistic=13.714276913108387, pvalue=0.0033210316273583032)
# FlignerResult(statistic=8.282425909417634, pvalue=0.04052155914922049)
# LeveneResult(statistic=3.3488815307154804, pvalue=0.02171632716905318)

# %% [markdown]
# 등분산성을 모두 만족하지 못한다고 볼수 있다.

# %%
# 정규성 검정
print(stats.shapiro(x1))
print(stats.shapiro(x2))
print(stats.shapiro(x3))
print(stats.shapiro(x4))
# Out:
# ShapiroResult(statistic=0.8234704732894897, pvalue=0.0004537469649221748)
# ShapiroResult(statistic=0.8676064610481262, pvalue=0.0021644863300025463)
# ShapiroResult(statistic=0.8433816432952881, pvalue=0.00045206016511656344)
# ShapiroResult(statistic=0.8501361012458801, pvalue=0.0006241131923161447)

# %% [markdown]
# 모두 정규분포를 만족하지 못한다.

# %%
group1=harvest_cnt[harvest_cnt['샘플']=='1']['개수']
group4=harvest_cnt[harvest_cnt['샘플']=='4']['개수']
group7=harvest_cnt[harvest_cnt['샘플']=='7']['개수']
group10=harvest_cnt[harvest_cnt['샘플']=='10']['개수']

# %%
stats.kruskal(group1, group4, group7,group10)
# Out:
# KruskalResult(statistic=2.3066234902278984, pvalue=0.511253209794831)

# %%
import scikit_posthocs as sp

# %%
# 위에서 그룹간 차이를 보이지 않았지만 사후검정을 해보았다.
sp.posthoc_conover(harvest_cnt,
                  val_col = '개수',
                  group_col = '샘플',
                  p_adjust = 'holm')
# Out:
#            1   10    4         7
# 1   1.000000  1.0  1.0  0.945648
# 10  1.000000  1.0  1.0  1.000000
# 4   1.000000  1.0  1.0  1.000000
# 7   0.945648  1.0  1.0  1.000000

# %% [markdown]
# 샘플별 수확 갯수에 차이가 없다
